# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("alzheimer.csv")

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Age'], df['CDR'], color='red', marker='o')
plt.title('CDR vs Age')
plt.ylabel('Age')
plt.xlabel('CDR')
# Out:
# Text(0.5, 0, 'CDR')

# %%
df['Group'] = df['Group'].map({'Nondemented': 0, 'Converted': 1, 'Demented': 2})

# %%
df.corr()['Group'].sort_values().plot(kind="bar")
# Out:
# C:\Users\ADMİN\AppData\Local\Temp\ipykernel_53708\1312596844.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Group'].sort_values().plot(kind="bar")
# <Axes: >

# %%
import seaborn as sns
plt.figure(figsize=(4,4))
sns.countplot(data=df, x='Group')
plt.title('Hastalık Evrelerine Göre Dağılım')
plt.xlabel('Hastalık Durumu')
plt.ylabel('Sayı')
# Out:
# Text(0, 0.5, 'Sayı')

# %%
plt.figure(figsize=(3,3))
df['M/F'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Cinsiyet Dağılımı')
# Out:
# Text(0.5, 1.0, 'Cinsiyet Dağılımı')

# %%
import seaborn as sns
plt.figure(figsize=(4,4))
sns.countplot(data=df, x='SES')
# Out:
# <Axes: xlabel='SES', ylabel='count'>

# %%
import seaborn as sns
plt.figure(figsize=(7,7))
sns.countplot(data=df, x='MMSE')
# Out:
# <Axes: xlabel='MMSE', ylabel='count'>

# %%
plt.figure(figsize=(6,6))
sns.distplot(df["MMSE"])
# Out:
# C:\Users\ADMİN\AppData\Local\Temp\ipykernel_53708\1503956541.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["MMSE"])
# <Axes: xlabel='MMSE', ylabel='Density'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df, x='EDUC', hue='Group')
plt.title('Eğitim Durumunun Hastalığın Evrelerine Göre Dağılımı')
plt.xlabel('Eğitim Durumu')
plt.ylabel('Sayı')
plt.legend(title='Hastalık Durumu')

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=df, x='EDUC', bins=10, kde=True)
plt.title('Eğitim Durumu')
plt.xlabel('EDUC')
plt.ylabel('Frekans')
# Out:
# Text(0, 0.5, 'Frekans')

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cbar_kws={'shrink': .75}, fmt='.3f')
plt.show()
# Out:
# C:\Users\ADMİN\AppData\Local\Temp\ipykernel_53708\951353859.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cbar_kws={'shrink': .75}, fmt='.3f')

# %%
plt.figure(figsize=(3,3))
df['CDR'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('CDR Dağılımı')
# Out:
# Text(0.5, 1.0, 'CDR Dağılımı')

# %%
plt.figure(figsize=(3,3))
df['SES'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('SES Dağılımı')
# Out:
# Text(0.5, 1.0, 'SES Dağılımı')

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=df, x='SES', bins=10, kde=True)
plt.title('SES Durumu')
plt.xlabel('SES')
plt.ylabel('Frekans')
# Out:
# Text(0, 0.5, 'Frekans')

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=df, x='CDR', bins=10, kde=True)
plt.title('CDR Durumu')
plt.xlabel('CDR')
plt.ylabel('Frekans')
# Out:
# Text(0, 0.5, 'Frekans')

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=df, x='Age', bins=10, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=df , x='Age')
plt.title('Hastalığın Yaşa  Göre Dağılımı')
plt.xlabel('Yaş Durumu')
plt.ylabel('Sayı')
# Out:
# Text(0, 0.5, 'Sayı')

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df , x='M/F')
plt.title('Hastalığın Cinsiyetine Göre Dağılımı')
plt.xlabel('Cinsiyet Durumu')
plt.ylabel('Sayı')
# Out:
# Text(0, 0.5, 'Sayı')

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=df , x='CDR')
plt.title('Hastalığın CDR Durumuna  Göre Dağılımı')
plt.xlabel('Hastalık Durumu')
plt.ylabel('Sayı')
# Out:
# Text(0, 0.5, 'Sayı')

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df, x='Group', y='SES')
plt.title('SES Skorları Dağılımı')
plt.xlabel('Hastalık Durumu')
plt.ylabel('SES Skoru')
# Out:
# Text(0, 0.5, 'SES Skoru')

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df, x='Group', y='Age')
plt.title('Age Skorları Dağılımı')
plt.xlabel('Hastalık Durumu')
plt.ylabel('Age Skoru')
# Out:
# Text(0, 0.5, 'Age Skoru')

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df, x='Group', y='ASF')
plt.title('ASF Skorları Dağılımı')
plt.xlabel('Hastalık Durumu')
plt.ylabel('ASF Skoru')
# Out:
# Text(0, 0.5, 'ASF Skoru')

# %%
plt.scatter(df.Age,df.EDUC,s=75,c="m",marker="v",edgecolor="black",linewidths=1)
plt.xlabel('Yaş')
plt.ylabel('Eğitim Seviyesi')
plt.title('Yaş-Eğitim  Durumu Dağılımı')
# Out:
# Text(0.5, 1.0, 'Yaş-Eğitim  Durumu Dağılımı')

# %%
plt.scatter(df.EDUC,df.MMSE,s=75,c="r",marker="o",edgecolor="red",linewidths=1)
